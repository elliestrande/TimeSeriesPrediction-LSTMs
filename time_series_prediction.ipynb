# %% [markdown]
# ## Time Series Prediction with LSTM Recurrent Neural Networks

# %%
import pandas
import matplotlib.pyplot as plt
dataset = pandas.read_csv('airline-passengers.csv', usecols=[1], engine='python')
plt.plot(dataset)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
# fix random seed for reproducibility
tf.random.set_seed(7)

# %%
# load the dataset
dataframe = pd.read_csv('airline-passengers.csv', usecols=[1], engine='python')
dataset = dataframe.values
dataset = dataset.astype('float32')

# %%
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# %%
# split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
print(len(train), len(test))
# Out:
# 96 48

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
 dataX, dataY = [], []
 for i in range(len(dataset)-look_back-1):
    a = dataset[i:(i+look_back), 0]
    dataX.append(a)
    dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# %%
# reshape into X=t and Y=t+1
look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# %%
# reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)
# Out:
# Metal device set to: Apple M2
#
# systemMemory: 8.00 GB
# maxCacheSize: 2.67 GB
#
# Epoch 1/100
# 2023-04-19 10:17:08.170423: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 1/1 - 2s - loss: 6.0184e-04 - 2s/epoch - 2s/step
# Epoch 2/100
# 1/1 - 0s - loss: 5.2483e-04 - 41ms/epoch - 41ms/step
# Epoch 3/100
# 1/1 - 0s - loss: 4.5315e-04 - 6ms/epoch - 6ms/step
# Epoch 4/100
# 1/1 - 0s - loss: 3.8692e-04 - 6ms/epoch - 6ms/step
# Epoch 5/100
# 1/1 - 0s - loss: 3.2621e-04 - 6ms/epoch - 6ms/step
# Epoch 6/100
# 1/1 - 0s - loss: 2.7106e-04 - 5ms/epoch - 5ms/step
# Epoch 7/100
# 1/1 - 0s - loss: 2.2148e-04 - 5ms/epoch - 5ms/step
# Epoch 8/100
# 1/1 - 0s - loss: 1.7745e-04 - 10ms/epoch - 10ms/step
# Epoch 9/100
# 1/1 - 0s - loss: 1.3889e-04 - 5ms/epoch - 5ms/step
# Epoch 10/100
# 1/1 - 0s - loss: 1.0567e-04 - 6ms/epoch - 6ms/step
# Epoch 11/100
# 1/1 - 0s - loss: 7.7636e-05 - 5ms/epoch - 5ms/step
# Epoch 12/100
# 1/1 - 0s - loss: 5.4545e-05 - 6ms/epoch - 6ms/step
# Epoch 13/100
# 1/1 - 0s - loss: 3.6115e-05 - 9ms/epoch - 9ms/step
# Epoch 14/100
# 1/1 - 0s - loss: 2.1999e-05 - 10ms/epoch - 10ms/step
# Epoch 15/100
# 1/1 - 0s - loss: 1.1800e-05 - 11ms/epoch - 11ms/step
# Epoch 16/100
# 1/1 - 0s - loss: 5.0678e-06 - 6ms/epoch - 6ms/step
# Epoch 17/100
# 1/1 - 0s - loss: 1.3120e-06 - 6ms/epoch - 6ms/step
# Epoch 18/100
# 1/1 - 0s - loss: 1.5520e-08 - 5ms/epoch - 5ms/step
# Epoch 19/100
# 1/1 - 0s - loss: 6.4877e-07 - 5ms/epoch - 5ms/step
# Epoch 20/100
# 1/1 - 0s - loss: 2.6882e-06 - 8ms/epoch - 8ms/step
# Epoch 21/100
# 1/1 - 0s - loss: 5.6350e-06 - 5ms/epoch - 5ms/step
# Epoch 22/100
# 1/1 - 0s - loss: 9.0338e-06 - 6ms/epoch - 6ms/step
# Epoch 23/100
# 1/1 - 0s - loss: 1.2489e-05 - 5ms/epoch - 5ms/step
# Epoch 24/100
# 1/1 - 0s - loss: 1.5674e-05 - 5ms/epoch - 5ms/step
# Epoch 25/100
# 1/1 - 0s - loss: 1.8345e-05 - 5ms/epoch - 5ms/step
# Epoch 26/100
# 1/1 - 0s - loss: 2.0335e-05 - 5ms/epoch - 5ms/step
# Epoch 27/100
# 1/1 - 0s - loss: 2.1554e-05 - 5ms/epoch - 5ms/step
# Epoch 28/100
# 1/1 - 0s - loss: 2.1983e-05 - 5ms/epoch - 5ms/step
# Epoch 29/100
# 1/1 - 0s - loss: 2.1660e-05 - 5ms/epoch - 5ms/step
# Epoch 30/100
# 1/1 - 0s - loss: 2.0669e-05 - 6ms/epoch - 6ms/step
# Epoch 31/100
# 1/1 - 0s - loss: 1.9127e-05 - 6ms/epoch - 6ms/step
# Epoch 32/100
# 1/1 - 0s - loss: 1.7171e-05 - 5ms/epoch - 5ms/step
# Epoch 33/100
# 1/1 - 0s - loss: 1.4945e-05 - 5ms/epoch - 5ms/step
# Epoch 34/100
# 1/1 - 0s - loss: 1.2588e-05 - 6ms/epoch - 6ms/step
# Epoch 35/100
# 1/1 - 0s - loss: 1.0233e-05 - 5ms/epoch - 5ms/step
# Epoch 36/100
# 1/1 - 0s - loss: 7.9906e-06 - 5ms/epoch - 5ms/step
# Epoch 37/100
# 1/1 - 0s - loss: 5.9516e-06 - 5ms/epoch - 5ms/step
# Epoch 38/100
# 1/1 - 0s - loss: 4.1825e-06 - 6ms/epoch - 6ms/step
# Epoch 39/100
# 1/1 - 0s - loss: 2.7239e-06 - 5ms/epoch - 5ms/step
# Epoch 40/100
# 1/1 - 0s - loss: 1.5934e-06 - 6ms/epoch - 6ms/step
# Epoch 41/100
# 1/1 - 0s - loss: 7.8636e-07 - 5ms/epoch - 5ms/step
# Epoch 42/100
# 1/1 - 0s - loss: 2.8016e-07 - 7ms/epoch - 7ms/step
# Epoch 43/100
# 1/1 - 0s - loss: 3.7892e-08 - 11ms/epoch - 11ms/step
# Epoch 44/100
# 1/1 - 0s - loss: 1.2801e-08 - 6ms/epoch - 6ms/step
# Epoch 45/100
# 1/1 - 0s - loss: 1.5272e-07 - 5ms/epoch - 5ms/step
# Epoch 46/100
# 1/1 - 0s - loss: 4.0421e-07 - 5ms/epoch - 5ms/step
# Epoch 47/100
# 1/1 - 0s - loss: 7.1626e-07 - 5ms/epoch - 5ms/step
# Epoch 48/100
# 1/1 - 0s - loss: 1.0432e-06 - 5ms/epoch - 5ms/step
# Epoch 49/100
# 1/1 - 0s - loss: 1.3471e-06 - 5ms/epoch - 5ms/step
# Epoch 50/100
# 1/1 - 0s - loss: 1.5989e-06 - 5ms/epoch - 5ms/step
# Epoch 51/100
# 1/1 - 0s - loss: 1.7792e-06 - 5ms/epoch - 5ms/step
# Epoch 52/100
# 1/1 - 0s - loss: 1.8778e-06 - 6ms/epoch - 6ms/step
# Epoch 53/100
# 1/1 - 0s - loss: 1.8933e-06 - 5ms/epoch - 5ms/step
# Epoch 54/100
# 1/1 - 0s - loss: 1.8311e-06 - 5ms/epoch - 5ms/step
# Epoch 55/100
# 1/1 - 0s - loss: 1.7026e-06 - 5ms/epoch - 5ms/step
# Epoch 56/100
# 1/1 - 0s - loss: 1.5228e-06 - 5ms/epoch - 5ms/step
# Epoch 57/100
# 1/1 - 0s - loss: 1.3089e-06 - 6ms/epoch - 6ms/step
# Epoch 58/100
# 1/1 - 0s - loss: 1.0781e-06 - 5ms/epoch - 5ms/step
# Epoch 59/100
# 1/1 - 0s - loss: 8.4706e-07 - 6ms/epoch - 6ms/step
# Epoch 60/100
# 1/1 - 0s - loss: 6.2981e-07 - 5ms/epoch - 5ms/step
# Epoch 61/100
# 1/1 - 0s - loss: 4.3744e-07 - 5ms/epoch - 5ms/step
# Epoch 62/100
# 1/1 - 0s - loss: 2.7773e-07 - 5ms/epoch - 5ms/step
# Epoch 63/100
# 1/1 - 0s - loss: 1.5483e-07 - 6ms/epoch - 6ms/step
# Epoch 64/100
# 1/1 - 0s - loss: 6.9476e-08 - 5ms/epoch - 5ms/step
# Epoch 65/100
# 1/1 - 0s - loss: 1.9554e-08 - 5ms/epoch - 5ms/step
# Epoch 66/100
# 1/1 - 0s - loss: 5.9630e-10 - 5ms/epoch - 5ms/step
# Epoch 67/100
# 1/1 - 0s - loss: 6.5358e-09 - 5ms/epoch - 5ms/step
# Epoch 68/100
# 1/1 - 0s - loss: 3.0447e-08 - 6ms/epoch - 6ms/step
# Epoch 69/100
# 1/1 - 0s - loss: 6.5233e-08 - 5ms/epoch - 5ms/step
# Epoch 70/100
# 1/1 - 0s - loss: 1.0423e-07 - 6ms/epoch - 6ms/step
# Epoch 71/100
# 1/1 - 0s - loss: 1.4169e-07 - 5ms/epoch - 5ms/step
# Epoch 72/100
# 1/1 - 0s - loss: 1.7316e-07 - 8ms/epoch - 8ms/step
# Epoch 73/100
# 1/1 - 0s - loss: 1.9553e-07 - 11ms/epoch - 11ms/step
# Epoch 74/100
# 1/1 - 0s - loss: 2.0727e-07 - 6ms/epoch - 6ms/step
# Epoch 75/100
# 1/1 - 0s - loss: 2.0809e-07 - 5ms/epoch - 5ms/step
# Epoch 76/100
# 1/1 - 0s - loss: 1.9882e-07 - 5ms/epoch - 5ms/step
# Epoch 77/100
# 1/1 - 0s - loss: 1.8118e-07 - 6ms/epoch - 6ms/step
# Epoch 78/100
# 1/1 - 0s - loss: 1.5752e-07 - 5ms/epoch - 5ms/step
# Epoch 79/100
# 1/1 - 0s - loss: 1.3032e-07 - 6ms/epoch - 6ms/step
# Epoch 80/100
# 1/1 - 0s - loss: 1.0207e-07 - 5ms/epoch - 5ms/step
# Epoch 81/100
# 1/1 - 0s - loss: 7.5000e-08 - 5ms/epoch - 5ms/step
# Epoch 82/100
# 1/1 - 0s - loss: 5.0919e-08 - 5ms/epoch - 5ms/step
# Epoch 83/100
# 1/1 - 0s - loss: 3.1055e-08 - 5ms/epoch - 5ms/step
# Epoch 84/100
# 1/1 - 0s - loss: 1.6127e-08 - 5ms/epoch - 5ms/step
# Epoch 85/100
# 1/1 - 0s - loss: 6.2685e-09 - 6ms/epoch - 6ms/step
# Epoch 86/100
# 1/1 - 0s - loss: 1.1409e-09 - 5ms/epoch - 5ms/step
# Epoch 87/100
# 1/1 - 0s - loss: 6.7260e-11 - 5ms/epoch - 5ms/step
# Epoch 88/100
# 1/1 - 0s - loss: 2.1141e-09 - 6ms/epoch - 6ms/step
# Epoch 89/100
# 1/1 - 0s - loss: 6.2284e-09 - 5ms/epoch - 5ms/step
# Epoch 90/100
# 1/1 - 0s - loss: 1.1386e-08 - 7ms/epoch - 7ms/step
# Epoch 91/100
# 1/1 - 0s - loss: 1.6640e-08 - 5ms/epoch - 5ms/step
# Epoch 92/100
# 1/1 - 0s - loss: 2.1240e-08 - 6ms/epoch - 6ms/step
# Epoch 93/100
# 1/1 - 0s - loss: 2.4642e-08 - 5ms/epoch - 5ms/step
# Epoch 94/100
# 1/1 - 0s - loss: 2.6536e-08 - 5ms/epoch - 5ms/step
# Epoch 95/100
# 1/1 - 0s - loss: 2.6832e-08 - 5ms/epoch - 5ms/step
# Epoch 96/100
# 1/1 - 0s - loss: 2.5645e-08 - 5ms/epoch - 5ms/step
# Epoch 97/100
# 1/1 - 0s - loss: 2.3236e-08 - 5ms/epoch - 5ms/step
# Epoch 98/100
# 1/1 - 0s - loss: 1.9946e-08 - 7ms/epoch - 7ms/step
# Epoch 99/100
# 1/1 - 0s - loss: 1.6171e-08 - 5ms/epoch - 5ms/step
# Epoch 100/100
# 1/1 - 0s - loss: 1.2301e-08 - 12ms/epoch - 12ms/step

# %%
# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# calculate root mean squared error
trainScore = np.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = np.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 11ms/step
# Train Score: 0.05 RMSE
# Test Score: 145.38 RMSE

# %%
# shift train predictions for plotting
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
# LSTM for international airline passengers problem with regression framing
import numpy as np
import matplotlib.pyplot as plt
from pandas import read_csv
import math
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
 dataX, dataY = [], []
 for i in range(len(dataset)-look_back-1):
    a = dataset[i:(i+look_back), 0]
    dataX.append(a)
    dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)
# fix random seed for reproducibility
tf.random.set_seed(7)
# load the dataset
dataframe = read_csv('airline-passengers.csv', usecols=[1], engine='python')
dataset = dataframe.values
dataset = dataset.astype('float32')
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
# split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
# reshape into X=t and Y=t+1
look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
# reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)
# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# calculate root mean squared error
trainScore = np.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = np.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# shift train predictions for plotting
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# Epoch 1/100
# 1/1 - 0s - loss: 8.5620e-04 - 422ms/epoch - 422ms/step
# Epoch 2/100
# 1/1 - 0s - loss: 7.6884e-04 - 6ms/epoch - 6ms/step
# Epoch 3/100
# 1/1 - 0s - loss: 6.8642e-04 - 5ms/epoch - 5ms/step
# Epoch 4/100
# 1/1 - 0s - loss: 6.0899e-04 - 6ms/epoch - 6ms/step
# Epoch 5/100
# 1/1 - 0s - loss: 5.3659e-04 - 5ms/epoch - 5ms/step
# Epoch 6/100
# 1/1 - 0s - loss: 4.6924e-04 - 8ms/epoch - 8ms/step
# Epoch 7/100
# 1/1 - 0s - loss: 4.0691e-04 - 5ms/epoch - 5ms/step
# Epoch 8/100
# 1/1 - 0s - loss: 3.4958e-04 - 5ms/epoch - 5ms/step
# Epoch 9/100
# 1/1 - 0s - loss: 2.9719e-04 - 5ms/epoch - 5ms/step
# Epoch 10/100
# 1/1 - 0s - loss: 2.4968e-04 - 5ms/epoch - 5ms/step
# Epoch 11/100
# 1/1 - 0s - loss: 2.0695e-04 - 6ms/epoch - 6ms/step
# Epoch 12/100
# 1/1 - 0s - loss: 1.6890e-04 - 5ms/epoch - 5ms/step
# Epoch 13/100
# 1/1 - 0s - loss: 1.3539e-04 - 5ms/epoch - 5ms/step
# Epoch 14/100
# 1/1 - 0s - loss: 1.0626e-04 - 5ms/epoch - 5ms/step
# Epoch 15/100
# 1/1 - 0s - loss: 8.1308e-05 - 6ms/epoch - 6ms/step
# Epoch 16/100
# 1/1 - 0s - loss: 6.0321e-05 - 5ms/epoch - 5ms/step
# Epoch 17/100
# 1/1 - 0s - loss: 4.3044e-05 - 6ms/epoch - 6ms/step
# Epoch 18/100
# 1/1 - 0s - loss: 2.9200e-05 - 5ms/epoch - 5ms/step
# Epoch 19/100
# 1/1 - 0s - loss: 1.8485e-05 - 6ms/epoch - 6ms/step
# Epoch 20/100
# 1/1 - 0s - loss: 1.0575e-05 - 6ms/epoch - 6ms/step
# Epoch 21/100
# 1/1 - 0s - loss: 5.1310e-06 - 6ms/epoch - 6ms/step
# Epoch 22/100
# 1/1 - 0s - loss: 1.8027e-06 - 6ms/epoch - 6ms/step
# Epoch 23/100
# 1/1 - 0s - loss: 2.3769e-07 - 6ms/epoch - 6ms/step
# Epoch 24/100
# 1/1 - 0s - loss: 8.8357e-08 - 5ms/epoch - 5ms/step
# Epoch 25/100
# 1/1 - 0s - loss: 1.0189e-06 - 8ms/epoch - 8ms/step
# Epoch 26/100
# 1/1 - 0s - loss: 2.7138e-06 - 5ms/epoch - 5ms/step
# Epoch 27/100
# 1/1 - 0s - loss: 4.8836e-06 - 5ms/epoch - 5ms/step
# Epoch 28/100
# 1/1 - 0s - loss: 7.2730e-06 - 5ms/epoch - 5ms/step
# Epoch 29/100
# 1/1 - 0s - loss: 9.6635e-06 - 6ms/epoch - 6ms/step
# Epoch 30/100
# 1/1 - 0s - loss: 1.1878e-05 - 5ms/epoch - 5ms/step
# Epoch 31/100
# 1/1 - 0s - loss: 1.3781e-05 - 5ms/epoch - 5ms/step
# Epoch 32/100
# 1/1 - 0s - loss: 1.5280e-05 - 5ms/epoch - 5ms/step
# Epoch 33/100
# 1/1 - 0s - loss: 1.6318e-05 - 8ms/epoch - 8ms/step
# Epoch 34/100
# 1/1 - 0s - loss: 1.6876e-05 - 9ms/epoch - 9ms/step
# Epoch 35/100
# 1/1 - 0s - loss: 1.6964e-05 - 8ms/epoch - 8ms/step
# Epoch 36/100
# 1/1 - 0s - loss: 1.6616e-05 - 5ms/epoch - 5ms/step
# Epoch 37/100
# 1/1 - 0s - loss: 1.5886e-05 - 5ms/epoch - 5ms/step
# Epoch 38/100
# 1/1 - 0s - loss: 1.4840e-05 - 5ms/epoch - 5ms/step
# Epoch 39/100
# 1/1 - 0s - loss: 1.3550e-05 - 5ms/epoch - 5ms/step
# Epoch 40/100
# 1/1 - 0s - loss: 1.2092e-05 - 6ms/epoch - 6ms/step
# Epoch 41/100
# 1/1 - 0s - loss: 1.0541e-05 - 5ms/epoch - 5ms/step
# Epoch 42/100
# 1/1 - 0s - loss: 8.9646e-06 - 5ms/epoch - 5ms/step
# Epoch 43/100
# 1/1 - 0s - loss: 7.4237e-06 - 5ms/epoch - 5ms/step
# Epoch 44/100
# 1/1 - 0s - loss: 5.9693e-06 - 6ms/epoch - 6ms/step
# Epoch 45/100
# 1/1 - 0s - loss: 4.6417e-06 - 5ms/epoch - 5ms/step
# Epoch 46/100
# 1/1 - 0s - loss: 3.4699e-06 - 5ms/epoch - 5ms/step
# Epoch 47/100
# 1/1 - 0s - loss: 2.4718e-06 - 5ms/epoch - 5ms/step
# Epoch 48/100
# 1/1 - 0s - loss: 1.6550e-06 - 5ms/epoch - 5ms/step
# Epoch 49/100
# 1/1 - 0s - loss: 1.0181e-06 - 5ms/epoch - 5ms/step
# Epoch 50/100
# 1/1 - 0s - loss: 5.5179e-07 - 5ms/epoch - 5ms/step
# Epoch 51/100
# 1/1 - 0s - loss: 2.4066e-07 - 5ms/epoch - 5ms/step
# Epoch 52/100
# 1/1 - 0s - loss: 6.4790e-08 - 5ms/epoch - 5ms/step
# Epoch 53/100
# 1/1 - 0s - loss: 1.3402e-09 - 5ms/epoch - 5ms/step
# Epoch 54/100
# 1/1 - 0s - loss: 2.6148e-08 - 5ms/epoch - 5ms/step
# Epoch 55/100
# 1/1 - 0s - loss: 1.1516e-07 - 5ms/epoch - 5ms/step
# Epoch 56/100
# 1/1 - 0s - loss: 2.4558e-07 - 5ms/epoch - 5ms/step
# Epoch 57/100
# 1/1 - 0s - loss: 3.9677e-07 - 5ms/epoch - 5ms/step
# Epoch 58/100
# 1/1 - 0s - loss: 5.5101e-07 - 5ms/epoch - 5ms/step
# Epoch 59/100
# 1/1 - 0s - loss: 6.9396e-07 - 5ms/epoch - 5ms/step
# Epoch 60/100
# 1/1 - 0s - loss: 8.1466e-07 - 5ms/epoch - 5ms/step
# Epoch 61/100
# 1/1 - 0s - loss: 9.0592e-07 - 5ms/epoch - 5ms/step
# Epoch 62/100
# 1/1 - 0s - loss: 9.6355e-07 - 5ms/epoch - 5ms/step
# Epoch 63/100
# 1/1 - 0s - loss: 9.8662e-07 - 5ms/epoch - 5ms/step
# Epoch 64/100
# 1/1 - 0s - loss: 9.7648e-07 - 6ms/epoch - 6ms/step
# Epoch 65/100
# 1/1 - 0s - loss: 9.3671e-07 - 11ms/epoch - 11ms/step
# Epoch 66/100
# 1/1 - 0s - loss: 8.7202e-07 - 7ms/epoch - 7ms/step
# Epoch 67/100
# 1/1 - 0s - loss: 7.8830e-07 - 6ms/epoch - 6ms/step
# Epoch 68/100
# 1/1 - 0s - loss: 6.9174e-07 - 5ms/epoch - 5ms/step
# Epoch 69/100
# 1/1 - 0s - loss: 5.8851e-07 - 5ms/epoch - 5ms/step
# Epoch 70/100
# 1/1 - 0s - loss: 4.8419e-07 - 5ms/epoch - 5ms/step
# Epoch 71/100
# 1/1 - 0s - loss: 3.8386e-07 - 5ms/epoch - 5ms/step
# Epoch 72/100
# 1/1 - 0s - loss: 2.9165e-07 - 6ms/epoch - 6ms/step
# Epoch 73/100
# 1/1 - 0s - loss: 2.1046e-07 - 5ms/epoch - 5ms/step
# Epoch 74/100
# 1/1 - 0s - loss: 1.4231e-07 - 6ms/epoch - 6ms/step
# Epoch 75/100
# 1/1 - 0s - loss: 8.8134e-08 - 6ms/epoch - 6ms/step
# Epoch 76/100
# 1/1 - 0s - loss: 4.7894e-08 - 5ms/epoch - 5ms/step
# Epoch 77/100
# 1/1 - 0s - loss: 2.0828e-08 - 6ms/epoch - 6ms/step
# Epoch 78/100
# 1/1 - 0s - loss: 5.5118e-09 - 5ms/epoch - 5ms/step
# Epoch 79/100
# 1/1 - 0s - loss: 8.9006e-11 - 6ms/epoch - 6ms/step
# Epoch 80/100
# 1/1 - 0s - loss: 2.4491e-09 - 6ms/epoch - 6ms/step
# Epoch 81/100
# 1/1 - 0s - loss: 1.0390e-08 - 6ms/epoch - 6ms/step
# Epoch 82/100
# 1/1 - 0s - loss: 2.1794e-08 - 7ms/epoch - 7ms/step
# Epoch 83/100
# 1/1 - 0s - loss: 3.4736e-08 - 6ms/epoch - 6ms/step
# Epoch 84/100
# 1/1 - 0s - loss: 4.7535e-08 - 7ms/epoch - 7ms/step
# Epoch 85/100
# 1/1 - 0s - loss: 5.8876e-08 - 5ms/epoch - 5ms/step
# Epoch 86/100
# 1/1 - 0s - loss: 6.7852e-08 - 6ms/epoch - 6ms/step
# Epoch 87/100
# 1/1 - 0s - loss: 7.3862e-08 - 6ms/epoch - 6ms/step
# Epoch 88/100
# 1/1 - 0s - loss: 7.6658e-08 - 5ms/epoch - 5ms/step
# Epoch 89/100
# 1/1 - 0s - loss: 7.6330e-08 - 5ms/epoch - 5ms/step
# Epoch 90/100
# 1/1 - 0s - loss: 7.3144e-08 - 6ms/epoch - 6ms/step
# Epoch 91/100
# 1/1 - 0s - loss: 6.7621e-08 - 6ms/epoch - 6ms/step
# Epoch 92/100
# 1/1 - 0s - loss: 6.0323e-08 - 5ms/epoch - 5ms/step
# Epoch 93/100
# 1/1 - 0s - loss: 5.1907e-08 - 5ms/epoch - 5ms/step
# Epoch 94/100
# 1/1 - 0s - loss: 4.2964e-08 - 6ms/epoch - 6ms/step
# Epoch 95/100
# 1/1 - 0s - loss: 3.4087e-08 - 11ms/epoch - 11ms/step
# Epoch 96/100
# 1/1 - 0s - loss: 2.5762e-08 - 8ms/epoch - 8ms/step
# Epoch 97/100
# 1/1 - 0s - loss: 1.8369e-08 - 8ms/epoch - 8ms/step
# Epoch 98/100
# 1/1 - 0s - loss: 1.2155e-08 - 8ms/epoch - 8ms/step
# Epoch 99/100
# 1/1 - 0s - loss: 7.2475e-09 - 5ms/epoch - 5ms/step
# Epoch 100/100
# 1/1 - 0s - loss: 3.6904e-09 - 6ms/epoch - 6ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 10ms/step
# Train Score: 0.02 RMSE
# Test Score: 208.19 RMSE

# %%
# LSTM for international airline passengers problem with window regression framing
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from pandas import read_csv
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
 dataX, dataY = [], []
 for i in range(len(dataset)-look_back-1):
    a = dataset[i:(i+look_back), 0]
    dataX.append(a)
    dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)
# fix random seed for reproducibility
tf.random.set_seed(7)
# load the dataset
dataframe = read_csv('airline-passengers.csv', usecols=[1], engine='python')
dataset = dataframe.values
dataset = dataset.astype('float32')
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
# split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
# reshape into X=t and Y=t+1
look_back = 3
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
# reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)
# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# calculate root mean squared error
trainScore = np.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = np.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# shift train predictions for plotting
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# Epoch 1/100
# 1/1 - 1s - loss: 0.0018 - 717ms/epoch - 717ms/step
# Epoch 2/100
# 1/1 - 0s - loss: 0.0017 - 6ms/epoch - 6ms/step
# Epoch 3/100
# 1/1 - 0s - loss: 0.0015 - 6ms/epoch - 6ms/step
# Epoch 4/100
# 1/1 - 0s - loss: 0.0014 - 6ms/epoch - 6ms/step
# Epoch 5/100
# 1/1 - 0s - loss: 0.0013 - 6ms/epoch - 6ms/step
# Epoch 6/100
# 1/1 - 0s - loss: 0.0012 - 7ms/epoch - 7ms/step
# Epoch 7/100
# 1/1 - 0s - loss: 0.0011 - 5ms/epoch - 5ms/step
# Epoch 8/100
# 1/1 - 0s - loss: 9.8332e-04 - 6ms/epoch - 6ms/step
# Epoch 9/100
# 1/1 - 0s - loss: 8.8728e-04 - 6ms/epoch - 6ms/step
# Epoch 10/100
# 1/1 - 0s - loss: 7.9676e-04 - 6ms/epoch - 6ms/step
# Epoch 11/100
# 1/1 - 0s - loss: 7.1174e-04 - 7ms/epoch - 7ms/step
# Epoch 12/100
# 1/1 - 0s - loss: 6.3223e-04 - 6ms/epoch - 6ms/step
# Epoch 13/100
# 1/1 - 0s - loss: 5.5817e-04 - 6ms/epoch - 6ms/step
# Epoch 14/100
# 1/1 - 0s - loss: 4.8952e-04 - 7ms/epoch - 7ms/step
# Epoch 15/100
# 1/1 - 0s - loss: 4.2622e-04 - 7ms/epoch - 7ms/step
# Epoch 16/100
# 1/1 - 0s - loss: 3.6816e-04 - 7ms/epoch - 7ms/step
# Epoch 17/100
# 1/1 - 0s - loss: 3.1524e-04 - 6ms/epoch - 6ms/step
# Epoch 18/100
# 1/1 - 0s - loss: 2.6733e-04 - 6ms/epoch - 6ms/step
# Epoch 19/100
# 1/1 - 0s - loss: 2.2426e-04 - 5ms/epoch - 5ms/step
# Epoch 20/100
# 1/1 - 0s - loss: 1.8587e-04 - 6ms/epoch - 6ms/step
# Epoch 21/100
# 1/1 - 0s - loss: 1.5194e-04 - 5ms/epoch - 5ms/step
# Epoch 22/100
# 1/1 - 0s - loss: 1.2227e-04 - 5ms/epoch - 5ms/step
# Epoch 23/100
# 1/1 - 0s - loss: 9.6615e-05 - 5ms/epoch - 5ms/step
# Epoch 24/100
# 1/1 - 0s - loss: 7.4718e-05 - 6ms/epoch - 6ms/step
# Epoch 25/100
# 1/1 - 0s - loss: 5.6312e-05 - 5ms/epoch - 5ms/step
# Epoch 26/100
# 1/1 - 0s - loss: 4.1116e-05 - 6ms/epoch - 6ms/step
# Epoch 27/100
# 1/1 - 0s - loss: 2.8841e-05 - 5ms/epoch - 5ms/step
# Epoch 28/100
# 1/1 - 0s - loss: 1.9192e-05 - 5ms/epoch - 5ms/step
# Epoch 29/100
# 1/1 - 0s - loss: 1.1871e-05 - 5ms/epoch - 5ms/step
# Epoch 30/100
# 1/1 - 0s - loss: 6.5831e-06 - 9ms/epoch - 9ms/step
# Epoch 31/100
# 1/1 - 0s - loss: 3.0392e-06 - 11ms/epoch - 11ms/step
# Epoch 32/100
# 1/1 - 0s - loss: 9.5886e-07 - 7ms/epoch - 7ms/step
# Epoch 33/100
# 1/1 - 0s - loss: 7.5265e-08 - 8ms/epoch - 8ms/step
# Epoch 34/100
# 1/1 - 0s - loss: 1.3754e-07 - 5ms/epoch - 5ms/step
# Epoch 35/100
# 1/1 - 0s - loss: 9.1420e-07 - 5ms/epoch - 5ms/step
# Epoch 36/100
# 1/1 - 0s - loss: 2.1956e-06 - 5ms/epoch - 5ms/step
# Epoch 37/100
# 1/1 - 0s - loss: 3.7955e-06 - 5ms/epoch - 5ms/step
# Epoch 38/100
# 1/1 - 0s - loss: 5.5528e-06 - 6ms/epoch - 6ms/step
# Epoch 39/100
# 1/1 - 0s - loss: 7.3315e-06 - 5ms/epoch - 5ms/step
# Epoch 40/100
# 1/1 - 0s - loss: 9.0209e-06 - 5ms/epoch - 5ms/step
# Epoch 41/100
# 1/1 - 0s - loss: 1.0536e-05 - 5ms/epoch - 5ms/step
# Epoch 42/100
# 1/1 - 0s - loss: 1.1814e-05 - 5ms/epoch - 5ms/step
# Epoch 43/100
# 1/1 - 0s - loss: 1.2813e-05 - 5ms/epoch - 5ms/step
# Epoch 44/100
# 1/1 - 0s - loss: 1.3512e-05 - 5ms/epoch - 5ms/step
# Epoch 45/100
# 1/1 - 0s - loss: 1.3906e-05 - 5ms/epoch - 5ms/step
# Epoch 46/100
# 1/1 - 0s - loss: 1.4005e-05 - 5ms/epoch - 5ms/step
# Epoch 47/100
# 1/1 - 0s - loss: 1.3829e-05 - 5ms/epoch - 5ms/step
# Epoch 48/100
# 1/1 - 0s - loss: 1.3406e-05 - 5ms/epoch - 5ms/step
# Epoch 49/100
# 1/1 - 0s - loss: 1.2774e-05 - 5ms/epoch - 5ms/step
# Epoch 50/100
# 1/1 - 0s - loss: 1.1970e-05 - 5ms/epoch - 5ms/step
# Epoch 51/100
# 1/1 - 0s - loss: 1.1035e-05 - 5ms/epoch - 5ms/step
# Epoch 52/100
# 1/1 - 0s - loss: 1.0010e-05 - 5ms/epoch - 5ms/step
# Epoch 53/100
# 1/1 - 0s - loss: 8.9321e-06 - 5ms/epoch - 5ms/step
# Epoch 54/100
# 1/1 - 0s - loss: 7.8378e-06 - 5ms/epoch - 5ms/step
# Epoch 55/100
# 1/1 - 0s - loss: 6.7580e-06 - 5ms/epoch - 5ms/step
# Epoch 56/100
# 1/1 - 0s - loss: 5.7197e-06 - 6ms/epoch - 6ms/step
# Epoch 57/100
# 1/1 - 0s - loss: 4.7447e-06 - 5ms/epoch - 5ms/step
# Epoch 58/100
# 1/1 - 0s - loss: 3.8499e-06 - 5ms/epoch - 5ms/step
# Epoch 59/100
# 1/1 - 0s - loss: 3.0470e-06 - 5ms/epoch - 5ms/step
# Epoch 60/100
# 1/1 - 0s - loss: 2.3434e-06 - 7ms/epoch - 7ms/step
# Epoch 61/100
# 1/1 - 0s - loss: 1.7421e-06 - 8ms/epoch - 8ms/step
# Epoch 62/100
# 1/1 - 0s - loss: 1.2421e-06 - 8ms/epoch - 8ms/step
# Epoch 63/100
# 1/1 - 0s - loss: 8.3964e-07 - 5ms/epoch - 5ms/step
# Epoch 64/100
# 1/1 - 0s - loss: 5.2809e-07 - 5ms/epoch - 5ms/step
# Epoch 65/100
# 1/1 - 0s - loss: 2.9907e-07 - 6ms/epoch - 6ms/step
# Epoch 66/100
# 1/1 - 0s - loss: 1.4281e-07 - 6ms/epoch - 6ms/step
# Epoch 67/100
# 1/1 - 0s - loss: 4.8615e-08 - 5ms/epoch - 5ms/step
# Epoch 68/100
# 1/1 - 0s - loss: 5.6818e-09 - 5ms/epoch - 5ms/step
# Epoch 69/100
# 1/1 - 0s - loss: 3.2423e-09 - 6ms/epoch - 6ms/step
# Epoch 70/100
# 1/1 - 0s - loss: 3.1074e-08 - 5ms/epoch - 5ms/step
# Epoch 71/100
# 1/1 - 0s - loss: 7.9749e-08 - 5ms/epoch - 5ms/step
# Epoch 72/100
# 1/1 - 0s - loss: 1.4088e-07 - 5ms/epoch - 5ms/step
# Epoch 73/100
# 1/1 - 0s - loss: 2.0732e-07 - 5ms/epoch - 5ms/step
# Epoch 74/100
# 1/1 - 0s - loss: 2.7299e-07 - 5ms/epoch - 5ms/step
# Epoch 75/100
# 1/1 - 0s - loss: 3.3318e-07 - 5ms/epoch - 5ms/step
# Epoch 76/100
# 1/1 - 0s - loss: 3.8455e-07 - 5ms/epoch - 5ms/step
# Epoch 77/100
# 1/1 - 0s - loss: 4.2463e-07 - 5ms/epoch - 5ms/step
# Epoch 78/100
# 1/1 - 0s - loss: 4.5220e-07 - 5ms/epoch - 5ms/step
# Epoch 79/100
# 1/1 - 0s - loss: 4.6692e-07 - 6ms/epoch - 6ms/step
# Epoch 80/100
# 1/1 - 0s - loss: 4.6908e-07 - 5ms/epoch - 5ms/step
# Epoch 81/100
# 1/1 - 0s - loss: 4.5976e-07 - 5ms/epoch - 5ms/step
# Epoch 82/100
# 1/1 - 0s - loss: 4.4041e-07 - 5ms/epoch - 5ms/step
# Epoch 83/100
# 1/1 - 0s - loss: 4.1268e-07 - 14ms/epoch - 14ms/step
# Epoch 84/100
# 1/1 - 0s - loss: 3.7849e-07 - 13ms/epoch - 13ms/step
# Epoch 85/100
# 1/1 - 0s - loss: 3.3986e-07 - 8ms/epoch - 8ms/step
# Epoch 86/100
# 1/1 - 0s - loss: 2.9867e-07 - 8ms/epoch - 8ms/step
# Epoch 87/100
# 1/1 - 0s - loss: 2.5664e-07 - 5ms/epoch - 5ms/step
# Epoch 88/100
# 1/1 - 0s - loss: 2.1533e-07 - 5ms/epoch - 5ms/step
# Epoch 89/100
# 1/1 - 0s - loss: 1.7609e-07 - 5ms/epoch - 5ms/step
# Epoch 90/100
# 1/1 - 0s - loss: 1.3991e-07 - 6ms/epoch - 6ms/step
# Epoch 91/100
# 1/1 - 0s - loss: 1.0754e-07 - 8ms/epoch - 8ms/step
# Epoch 92/100
# 1/1 - 0s - loss: 7.9480e-08 - 7ms/epoch - 7ms/step
# Epoch 93/100
# 1/1 - 0s - loss: 5.5973e-08 - 6ms/epoch - 6ms/step
# Epoch 94/100
# 1/1 - 0s - loss: 3.7048e-08 - 5ms/epoch - 5ms/step
# Epoch 95/100
# 1/1 - 0s - loss: 2.2493e-08 - 6ms/epoch - 6ms/step
# Epoch 96/100
# 1/1 - 0s - loss: 1.1999e-08 - 5ms/epoch - 5ms/step
# Epoch 97/100
# 1/1 - 0s - loss: 5.1084e-09 - 5ms/epoch - 5ms/step
# Epoch 98/100
# 1/1 - 0s - loss: 1.3004e-09 - 6ms/epoch - 6ms/step
# Epoch 99/100
# 1/1 - 0s - loss: 1.2630e-11 - 5ms/epoch - 5ms/step
# Epoch 100/100
# 1/1 - 0s - loss: 6.7246e-10 - 5ms/epoch - 5ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 10ms/step
# Train Score: 0.03 RMSE
# Test Score: 156.66 RMSE
